# %%
##Task: Given a concept (word), find the K (parameter) most frequent adjectives
#that appear with that noun (i.e., directly describe that noun) in the corpus of Amazon
#reviews (file: unlabeled_reviews.txt)


##Assignment: The concept (word) selected is 'PC'

# %%
# codecs library helps with reading from (or writing to) files with different encodings (e.g., UTF-8, ANSII, etc.)
import codecs

# specifying the location of the file containing our reviews
filepath = "unlabeled_reviews.txt"

# loading the content of the file and creating a list of texts from its lines (one review per line)
dataset = [l.strip() for l in list(codecs.open(filepath, "r", encoding = 'utf8', errors = 'replace').readlines())]

# let's see how many reviews we have in our dataset
print("We have: " + str(len(dataset)) + " reviews in the dataset.")
print()
      
# let's take a look at some concrete review
rev_index = 0
print(dataset[rev_index])
# Out:
# We have: 13153 reviews in the dataset.
#
# First of all why do you want a power UPS? There are some very good reasons. (1) You never want your machine to go down incorrectly because of a blackout. (2) You want to work with clean power only. (3) You want to monitor your PC power. (4) You want to prevent your PC from being damaged due to a power problem like a lighting strike and want surge protection. The first rule about UPS is to never trust the insurance claim. Get your PC insured elsewhere. These companies have a tendency not to support their insurance claims. I have a PC running some very high specifications with over six USB devices, LCD monitor, printer and Ethernet equipment, with everything on at the same time. I have never gone above 325W of usage and average between 250W and 300W when managing a high spec game and doing lots of background tasks. Even though I have a 400W Power Supply Unit (PSU) I will be upgrading to a 500W PSU because it is better quality model. The way I can monitor how many Watts I use is with UPS software and hardware. So the question you need to ask is how many watts you will be using. The short answer to this is you don't know until you install the UPS and software that tells you how many watts you use because that appears to be the only way you can monitor your wattage at this time. You need to estimate what it is. I would say a high-end domestic PC (not a server) would use 300W max if it has one of every device you can think off turned on. As soon as we add things like another PC, or several printers, or several monitors, then we can start to overload a 325W UPS. This brings us to the first thing we need to learn about any UPS - Overloading and balancing. The overload feature is a warning system that turns on when you have overloaded the UPS capacity. Overloading does two things. It can in theory eventually damage the UPS and it voids the warranty. Most UPS are 325W but there are 800W - 1000W and even greater models out there for home networks that use more than one PC setup but to be honest you are probably going to get a UPS per PC setup rather than expensive bigger UPS for a network. So check the UPS rating. What UPS you choose depends on how much you want to load on it. Next thing you need to check with the UPS is if it comes with a USB connection. If it does this is a big plus because it means you can control it from your PC and the UPS comes with software. Now if the UPS has this feature then you can do loads of stuff like turning off UPS sound alarms, controlling how your UPS handles a blackout, how long it uses the battery before shutdown or hibernation, if it sounds an alarm or not, if it run self tests, data collection and monitoring, notifications and sensitivity settings. If the UPS does not come with a USB connection and software then you probably should be looking for an UPS designed for computer use rather than a UPS for non-computer equipment. Most UPS have LED indicators that tell you the status of the unit. The next thing to understand is that testing your UPS is not done by breaking it out of the box, connecting it to the mains, plugging your PC in and then turning off the house's power with the circuit breaker. You must charge the UPS first! So read the instructions. Usually you must attach the battery to the UPS (plug it in firmly!) and wait before using it. Then perform the test using the software first! Then you can consider trying to simulate a blackout in your home to see if the PC stays up. Usually a UPS is programmed to shutdown your PC if the blackout lasts for a few seconds. Nearly all UPS models with a USB connection can be customized for the shutdown event or how long the PC should hold for on the UPS battery. Most UPS devices allow you to connect a modem phone line into the device and then run a phone line into your modem. This is important because power surges on a UPS that do not have this protection can damage a PC through the unprotected phone line running into the modem that usually runs to the PC  ...

# %%
# pip install wordcloud

# %%
# pip install matplotlib

# %% [markdown]
# Let's do a bit of explorative analysis of our dataset. Which electronic devices are most represented in the dataset?

# %%
# wordcloud is a Python library for generating word clouds from text
import wordcloud
from wordcloud import WordCloud

# matplotlib is a Python library for plotting / rendering data and graphs of all kinds
import matplotlib.pyplot as plt

# concatenating all our reviews into one long text
big_text = " ".join(dataset)

# creating an object of WordCloud which we will then depict: defining white background and feeding our big text
wcloud = WordCloud(collocations = False, background_color = "white", stopwords = []).generate_from_text(big_text)

# setting the size of the figure for wordclous plot
plt.figure(figsize=(8,7))

# plotting the created wordcloud
plt.imshow(wcloud, interpolation = "bilinear")
# we don't want to plot the axis
plt.axis("off")
# showing the plot
plt.show()

# %%
# import the list of English STOPWORDS from the wordcloud library
from wordcloud import STOPWORDS

# removing the repetitions if there are any, converting the list to set
stopwords = set(STOPWORDS)

# printing the list of stopwords
print(stopwords)
# Out:
# {'r', "they'll", "they've", 'an', "we'll", 'how', "wasn't", 'what', "isn't", 'not', "she's", "where's", 'being', 'yours', "can't", 'his', 'why', 'else', "you'll", 'also', 'are', 'her', "what's", 'would', 'ever', 'hence', 'ours', 'both', "how's", 'few', 'from', 'such', "hadn't", 'over', "wouldn't", 'him', "he'd", 'be', 'otherwise', 'same', "you've", 'hers', 'so', 'about', 'most', 'own', 'its', "i've", 'under', 'cannot', "haven't", 'com', 'she', 'these', 'this', 'http', 'k', 'am', 'been', "she'd", 'www', 'those', 'they', "she'll", 'their', 'through', 'therefore', 'having', 'my', 'once', 'further', 'have', 'each', 'but', 'between', "i'm", "you'd", 'any', 'at', 'just', 'very', 'get', 'against', 'on', 'during', 'you', 'like', 'where', "i'll", 'myself', "shouldn't", 'no', 'that', 'yourself', 'after', "don't", 'was', 'himself', 'again', 'too', 'the', 'herself', "won't", 'off', 'should', 'yourselves', "couldn't", "they're", "shan't", "when's", 'and', 'who', 'or', 'it', 'only', 'there', "he's", 'them', 'down', 'while', 'had', 'themselves', "who's", 'however', "aren't", 'if', "it's", 'theirs', 'ourselves', "mustn't", 'out', "they'd", 'does', "you're", 'he', 'can', 'more', 'until', 'to', 'as', 'were', "that's", "didn't", 'do', 'before', "let's", 'is', 'than', 'when', 'then', 'above', 'your', "i'd", 'up', 'a', 'we', 'did', 'me', "hasn't", 'into', 'in', 'has', "doesn't", "we'd", 'ought', 'with', 'nor', 'could', "we're", 'doing', "he'll", "here's", "why's", 'shall', 'since', 'all', "there's", 'by', 'below', 'other', 'which', 'our', 'here', 'some', 'of', "we've", "weren't", 'itself', 'whom', 'i', 'because', 'for'}

# %%
# setting the size of the figure for wordcloud plot
plt.figure(figsize=(8,7))

# creating an object of WordCloud which we will then depict: defining white background and feeding our big text
wcloud = WordCloud(max_words = 500, collocations = False, background_color = "white", stopwords = stopwords).generate_from_text(big_text)

# plotting the created wordcloud
plt.imshow(wcloud, interpolation = "bilinear")

# we don't want to plot the axis
plt.axis("off")

# showing the plot
plt.show()

# %%
# pip install spacy

# %%
# pip install -U spacy

# %%
#conda install -c conda-forge spacy

# %% [markdown]
# ### Text Preprocessing (tokenization, lemmatization / stemming stopword removal)
# let's break down the texts into tokens, normalize the texts (lemmatize or stem) and remove stopwords

# %%
# conda update -n base -c defaults conda

# %%
import spacy 

spacy.cli.download("en_core_web_sm")

nlp = spacy.load("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
## python -m spacy download en_core_web_sm

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
####### Tokenization

# we will use the SpaCy library for preprocessing and linguistic annotations
import spacy

# the default nlp pipeline will perform tokenization, POS-tagging, dependency parsing, and named entity recognition
nlp = spacy.load("en_core_web_sm")


tokenized_dataset = []
# if we just want tokenization, additional steps may slow the process, so we can use the "pipe" mode of SpaCy instead
# to eliminate POS-tagging, parsing, and NER
for doc in nlp.pipe(dataset, disable=["tagger", "parser", "ner"]):
    # t.text will give us the original text for each token in the text/document
    tokenized_dataset.append([t.text for t in doc])
    
print(tokenized_dataset[rev_index])
# Out:
# ['First', 'of', 'all', 'why', 'do', 'you', 'want', 'a', 'power', 'UPS', '?', 'There', 'are', 'some', 'very', 'good', 'reasons', '.', '(', '1', ')', 'You', 'never', 'want', 'your', 'machine', 'to', 'go', 'down', 'incorrectly', 'because', 'of', 'a', 'blackout', '.', '(', '2', ')', 'You', 'want', 'to', 'work', 'with', 'clean', 'power', 'only', '.', '(', '3', ')', 'You', 'want', 'to', 'monitor', 'your', 'PC', 'power', '.', '(', '4', ')', 'You', 'want', 'to', 'prevent', 'your', 'PC', 'from', 'being', 'damaged', 'due', 'to', 'a', 'power', 'problem', 'like', 'a', 'lighting', 'strike', 'and', 'want', 'surge', 'protection', '.', 'The', 'first', 'rule', 'about', 'UPS', 'is', 'to', 'never', 'trust', 'the', 'insurance', 'claim', '.', 'Get', 'your', 'PC', 'insured', 'elsewhere', '.', 'These', 'companies', 'have', 'a', 'tendency', 'not', 'to', 'support', 'their', 'insurance', 'claims', '.', 'I', 'have', 'a', 'PC', 'running', 'some', 'very', 'high', 'specifications', 'with', 'over', 'six', 'USB', 'devices', ',', 'LCD', 'monitor', ',', 'printer', 'and', 'Ethernet', 'equipment', ',', 'with', 'everything', 'on', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'never', 'gone', 'above', '325W', 'of', 'usage', 'and', 'average', 'between', '250W', 'and', '300W', 'when', 'managing', 'a', 'high', 'spec', 'game', 'and', 'doing', 'lots', 'of', 'background', 'tasks', '.', 'Even', 'though', 'I', 'have', 'a', '400W', 'Power', 'Supply', 'Unit', '(', 'PSU', ')', 'I', 'will', 'be', 'upgrading', 'to', 'a', '500W', 'PSU', 'because', 'it', 'is', 'better', 'quality', 'model', '.', 'The', 'way', 'I', 'can', 'monitor', 'how', 'many', 'Watts', 'I', 'use', 'is', 'with', 'UPS', 'software', 'and', 'hardware', '.', 'So', 'the', 'question', 'you', 'need', 'to', 'ask', 'is', 'how', 'many', 'watts', 'you', 'will', 'be', 'using', '.', 'The', 'short', 'answer', 'to', 'this', 'is', 'you', 'do', "n't", 'know', 'until', 'you', 'install', 'the', 'UPS', 'and', 'software', 'that', 'tells', 'you', 'how', 'many', 'watts', 'you', 'use', 'because', 'that', 'appears', 'to', 'be', 'the', 'only', 'way', 'you', 'can', 'monitor', 'your', 'wattage', 'at', 'this', 'time', '.', 'You', 'need', 'to', 'estimate', 'what', 'it', 'is', '.', 'I', 'would', 'say', 'a', 'high', '-', 'end', 'domestic', 'PC', '(', 'not', 'a', 'server', ')', 'would', 'use', '300W', 'max', 'if', 'it', 'has', 'one', 'of', 'every', 'device', 'you', 'can', 'think', 'off', 'turned', 'on', '.', 'As', 'soon', 'as', 'we', 'add', 'things', 'like', 'another', 'PC', ',', 'or', 'several', 'printers', ',', 'or', 'several', 'monitors', ',', 'then', 'we', 'can', 'start', 'to', 'overload', 'a', '325W', 'UPS', '.', 'This', 'brings', 'us', 'to', 'the', 'first', 'thing', 'we', 'need', 'to', 'learn', 'about', 'any', 'UPS', '-', 'Overloading', 'and', 'balancing', '.', 'The', 'overload', 'feature', 'is', 'a', 'warning', 'system', 'that', 'turns', 'on', 'when', 'you', 'have', 'overloaded', 'the', 'UPS', 'capacity', '.', 'Overloading', 'does', 'two', 'things', '.', 'It', 'can', 'in', 'theory', 'eventually', 'damage', 'the', 'UPS', 'and', 'it', 'voids', 'the', 'warranty', '.', 'Most', 'UPS', 'are', '325W', 'but', 'there', 'are', '800W', '-', '1000W', 'and', 'even', 'greater', 'models', 'out', 'there', 'for', 'home', 'networks', 'that', 'use', 'more', 'than', 'one', 'PC', 'setup', 'but', 'to', 'be', 'honest', 'you', 'are', 'probably', 'going', 'to', 'get', 'a', 'UPS', 'per', 'PC', 'setup', 'rather', 'than', 'expensive', 'bigger', 'UPS', 'for', 'a', 'network', '.', 'So', 'check', 'the', 'UPS', 'rating', '.', 'What', 'UPS', 'you', 'choose', 'depends', 'on', 'how', 'much', 'you', 'want', 'to', 'load', 'on', 'it', '.', 'Next', 'thing', 'you', 'need', 'to', 'check', 'with', 'the', 'UPS', 'is', 'if', 'it', 'comes', 'with', 'a', 'USB', 'connection', '.', 'If', 'it', 'does', 'this', 'is', 'a', 'big', 'plus', 'because', 'it', 'means', 'you', 'can', 'control', 'it', 'from', 'your', 'PC', 'and', 'the', 'UPS', 'comes', 'with', 'software', '.', 'Now', 'if', 't ...

# %%
###### Lemmatization

lemmatized_dataset = []
for doc in nlp.pipe(dataset, disable=["tagger", "parser", "ner"]):
    
    # t.lemma_ will give us the lemma for each token in the text/document
    lemmatized_dataset.append([t.lemma_ for t in doc])

print()
print(lemmatized_dataset[rev_index])
# Out:
# ['First', 'of', 'all', 'why', 'do', 'you', 'want', 'a', 'power', 'UPS', '?', 'There', 'be', 'some', 'very', 'good', 'reason', '.', '(', '1', ')', 'You', 'never', 'want', 'your', 'machine', 'to', 'go', 'down', 'incorrectly', 'because', 'of', 'a', 'blackout', '.', '(', '2', ')', 'You', 'want', 'to', 'work', 'with', 'clean', 'power', 'only', '.', '(', '3', ')', 'You', 'want', 'to', 'monitor', 'your', 'PC', 'power', '.', '(', '4', ')', 'You', 'want', 'to', 'prevent', 'your', 'PC', 'from', 'be', 'damage', 'due', 'to', 'a', 'power', 'problem', 'like', 'a', 'light', 'strike', 'and', 'want', 'surge', 'protection', '.', 'The', '\ufeff1', 'rule', 'about', 'UPS', 'be', 'to', 'never', 'trust', 'the', 'insurance', 'claim', '.', 'Get', 'your', 'PC', 'insure', 'elsewhere', '.', 'These', 'company', 'have', 'a', 'tendency', 'not', 'to', 'support', 'their', 'insurance', 'claim', '.', 'I', 'have', 'a', 'PC', 'run', 'some', 'very', 'high', 'specification', 'with', 'over', 'six', 'USB', 'device', ',', 'LCD', 'monitor', ',', 'printer', 'and', 'Ethernet', 'equipment', ',', 'with', 'everything', 'on', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'never', 'go', 'above', '325W', 'of', 'usage', 'and', 'average', 'between', '250W', 'and', '300W', 'when', 'manage', 'a', 'high', 'spec', 'game', 'and', 'do', 'lot', 'of', 'background', 'task', '.', 'Even', 'though', 'I', 'have', 'a', '400W', 'Power', 'Supply', 'Unit', '(', 'PSU', ')', 'I', 'will', 'be', 'upgrade', 'to', 'a', '500W', 'PSU', 'because', 'it', 'be', 'well', 'quality', 'model', '.', 'The', 'way', 'I', 'can', 'monitor', 'how', 'many', 'Watts', 'I', 'use', 'be', 'with', 'UPS', 'software', 'and', 'hardware', '.', 'So', 'the', 'question', 'you', 'need', 'to', 'ask', 'be', 'how', 'many', 'watt', 'you', 'will', 'be', 'use', '.', 'The', 'short', 'answer', 'to', 'this', 'be', 'you', 'do', 'not', 'know', 'until', 'you', 'install', 'the', 'UPS', 'and', 'software', 'that', 'tell', 'you', 'how', 'many', 'watt', 'you', 'use', 'because', 'that', 'appear', 'to', 'be', 'the', 'only', 'way', 'you', 'can', 'monitor', 'your', 'wattage', 'at', 'this', 'time', '.', 'You', 'need', 'to', 'estimate', 'what', 'it', 'be', '.', 'I', 'would', 'say', 'a', 'high', '-', 'end', 'domestic', 'PC', '(', 'not', 'a', 'server', ')', 'would', 'use', '300W', 'max', 'if', 'it', 'have', 'one', 'of', 'every', 'device', 'you', 'can', 'think', 'off', 'turn', 'on', '.', 'As', 'soon', 'a', 'we', 'add', 'thing', 'like', 'another', 'PC', ',', 'or', 'several', 'printer', ',', 'or', 'several', 'monitor', ',', 'then', 'we', 'can', 'start', 'to', 'overload', 'a', '325W', 'UPS', '.', 'This', 'bring', 'us', 'to', 'the', '\ufeff1', 'thing', 'we', 'need', 'to', 'learn', 'about', 'any', 'UPS', '-', 'Overloading', 'and', 'balance', '.', 'The', 'overload', 'feature', 'be', 'a', 'warn', 'system', 'that', 'turn', 'on', 'when', 'you', 'have', 'overload', 'the', 'UPS', 'capacity', '.', 'Overloading', 'doe', 'two', 'thing', '.', 'It', 'can', 'in', 'theory', 'eventually', 'damage', 'the', 'UPS', 'and', 'it', 'void', 'the', 'warranty', '.', 'Most', 'UPS', 'be', '325W', 'but', 'there', 'be', '800W', '-', '1000W', 'and', 'even', 'great', 'model', 'out', 'there', 'for', 'home', 'network', 'that', 'use', 'much', 'than', 'one', 'PC', 'setup', 'but', 'to', 'be', 'honest', 'you', 'be', 'probably', 'go', 'to', 'get', 'a', 'UPS', 'per', 'PC', 'setup', 'rather', 'than', 'expensive', 'big', 'UPS', 'for', 'a', 'network', '.', 'So', 'check', 'the', 'UPS', 'rate', '.', 'What', 'UPS', 'you', 'choose', 'depend', 'on', 'how', 'much', 'you', 'want', 'to', 'load', 'on', 'it', '.', 'Next', 'thing', 'you', 'need', 'to', 'check', 'with', 'the', 'UPS', 'be', 'if', 'it', 'come', 'with', 'a', 'USB', 'connection', '.', 'If', 'it', 'doe', 'this', 'be', 'a', 'big', 'plus', 'because', 'it', 'mean', 'you', 'can', 'control', 'it', 'from', 'your', 'PC', 'and', 'the', 'UPS', 'come', 'with', 'software', '.', 'Now', 'if', 'the', 'UPS', 'have', 'this', 'feature', 'then', 'you', 'can', 'do', 'loa ...

# %%
####### Stemming 

# we will use the Porter stemmer from the NLTK library
import nltk
from nltk.stem.porter import *

# instantiate the stemmer object
stemmer = PorterStemmer()

stemmed_dataset = []
for doc in nlp.pipe(dataset, disable=["tagger", "parser", "ner"]):
    
    # t.text will give us the raw token text which we then stem with the stemmer
    stemmed_dataset.append([stemmer.stem(t.text) for t in doc])

print()
print(stemmed_dataset[rev_index])
# Out:
# ['first', 'of', 'all', 'whi', 'do', 'you', 'want', 'a', 'power', 'up', '?', 'there', 'are', 'some', 'veri', 'good', 'reason', '.', '(', '1', ')', 'you', 'never', 'want', 'your', 'machin', 'to', 'go', 'down', 'incorrectli', 'becaus', 'of', 'a', 'blackout', '.', '(', '2', ')', 'you', 'want', 'to', 'work', 'with', 'clean', 'power', 'onli', '.', '(', '3', ')', 'you', 'want', 'to', 'monitor', 'your', 'PC', 'power', '.', '(', '4', ')', 'you', 'want', 'to', 'prevent', 'your', 'PC', 'from', 'be', 'damag', 'due', 'to', 'a', 'power', 'problem', 'like', 'a', 'light', 'strike', 'and', 'want', 'surg', 'protect', '.', 'the', 'first', 'rule', 'about', 'up', 'is', 'to', 'never', 'trust', 'the', 'insur', 'claim', '.', 'get', 'your', 'PC', 'insur', 'elsewher', '.', 'these', 'compani', 'have', 'a', 'tendenc', 'not', 'to', 'support', 'their', 'insur', 'claim', '.', 'I', 'have', 'a', 'PC', 'run', 'some', 'veri', 'high', 'specif', 'with', 'over', 'six', 'usb', 'devic', ',', 'lcd', 'monitor', ',', 'printer', 'and', 'ethernet', 'equip', ',', 'with', 'everyth', 'on', 'at', 'the', 'same', 'time', '.', 'I', 'have', 'never', 'gone', 'abov', '325w', 'of', 'usag', 'and', 'averag', 'between', '250w', 'and', '300w', 'when', 'manag', 'a', 'high', 'spec', 'game', 'and', 'do', 'lot', 'of', 'background', 'task', '.', 'even', 'though', 'I', 'have', 'a', '400w', 'power', 'suppli', 'unit', '(', 'psu', ')', 'I', 'will', 'be', 'upgrad', 'to', 'a', '500w', 'psu', 'becaus', 'it', 'is', 'better', 'qualiti', 'model', '.', 'the', 'way', 'I', 'can', 'monitor', 'how', 'mani', 'watt', 'I', 'use', 'is', 'with', 'up', 'softwar', 'and', 'hardwar', '.', 'So', 'the', 'question', 'you', 'need', 'to', 'ask', 'is', 'how', 'mani', 'watt', 'you', 'will', 'be', 'use', '.', 'the', 'short', 'answer', 'to', 'thi', 'is', 'you', 'do', "n't", 'know', 'until', 'you', 'instal', 'the', 'up', 'and', 'softwar', 'that', 'tell', 'you', 'how', 'mani', 'watt', 'you', 'use', 'becaus', 'that', 'appear', 'to', 'be', 'the', 'onli', 'way', 'you', 'can', 'monitor', 'your', 'wattag', 'at', 'thi', 'time', '.', 'you', 'need', 'to', 'estim', 'what', 'it', 'is', '.', 'I', 'would', 'say', 'a', 'high', '-', 'end', 'domest', 'PC', '(', 'not', 'a', 'server', ')', 'would', 'use', '300w', 'max', 'if', 'it', 'ha', 'one', 'of', 'everi', 'devic', 'you', 'can', 'think', 'off', 'turn', 'on', '.', 'As', 'soon', 'as', 'we', 'add', 'thing', 'like', 'anoth', 'PC', ',', 'or', 'sever', 'printer', ',', 'or', 'sever', 'monitor', ',', 'then', 'we', 'can', 'start', 'to', 'overload', 'a', '325w', 'up', '.', 'thi', 'bring', 'us', 'to', 'the', 'first', 'thing', 'we', 'need', 'to', 'learn', 'about', 'ani', 'up', '-', 'overload', 'and', 'balanc', '.', 'the', 'overload', 'featur', 'is', 'a', 'warn', 'system', 'that', 'turn', 'on', 'when', 'you', 'have', 'overload', 'the', 'up', 'capac', '.', 'overload', 'doe', 'two', 'thing', '.', 'It', 'can', 'in', 'theori', 'eventu', 'damag', 'the', 'up', 'and', 'it', 'void', 'the', 'warranti', '.', 'most', 'up', 'are', '325w', 'but', 'there', 'are', '800w', '-', '1000w', 'and', 'even', 'greater', 'model', 'out', 'there', 'for', 'home', 'network', 'that', 'use', 'more', 'than', 'one', 'PC', 'setup', 'but', 'to', 'be', 'honest', 'you', 'are', 'probabl', 'go', 'to', 'get', 'a', 'up', 'per', 'PC', 'setup', 'rather', 'than', 'expens', 'bigger', 'up', 'for', 'a', 'network', '.', 'So', 'check', 'the', 'up', 'rate', '.', 'what', 'up', 'you', 'choos', 'depend', 'on', 'how', 'much', 'you', 'want', 'to', 'load', 'on', 'it', '.', 'next', 'thing', 'you', 'need', 'to', 'check', 'with', 'the', 'up', 'is', 'if', 'it', 'come', 'with', 'a', 'usb', 'connect', '.', 'If', 'it', 'doe', 'thi', 'is', 'a', 'big', 'plu', 'becaus', 'it', 'mean', 'you', 'can', 'control', 'it', 'from', 'your', 'PC', 'and', 'the', 'up', 'come', 'with', 'softwar', '.', 'now', 'if', 'the', 'up', 'ha', 'thi', 'featur', 'then', 'you', 'can', 'do', 'load', 'of', 'stuff', 'like', 'turn', 'off', 'up', 'sound', 'alarm', ',', 'control', 'how', 'your', 'up' ...

# %% [markdown]
# ### Linguistic annotations: POS-tagging and dependency parsing
# SpaCy has pre-trained models for POS-tagging and dependency parsing

# %%
# parsing and pos-tagging may take longer on large datasets, so let's only demonstrate the functionality on first N reviews in our collection
N = 2
small_dataset = dataset[:N]

for doc in nlp.pipe(small_dataset, disable=["ner"]):
    # POS-tagging and parses are performed on a sentence-level (not document level, like tokenization)
    for sent in doc.sents:
        print(sent.text)
        print("------------------------------------")
        for tok in sent:
            # tok.i index of the token in the document
            # sent.start index of the starting token of the sentence in the document
            # tok.tag_ is the fine-grained POS-tag; 
            # tok.pos_ is the coarse-grained POS-tag; 
            # tok.dep_ is the dependency relation from the governing token to this token
            # tok.head is the token which is the syntactic head of the current token (.text is it's text, .i its index in the document)
            print(tok.i - sent.start, tok.text, tok.tag_, tok.pos_, tok.dep_, tok.head.text, "(" + str(tok.head.i - sent.start) + ")")
        print()
# Out:
# First of all why do you want a power UPS?
# ------------------------------------
# 0 First RB ADV advmod want (6)
# 1 of IN ADP prep First (0)
# 2 all DT DET pobj of (1)
# 3 why WRB ADV advmod want (6)
# 4 do VBP AUX aux want (6)
# 5 you PRP PRON nsubj want (6)
# 6 want VB VERB ROOT want (6)
# 7 a DT DET det UPS (9)
# 8 power NN NOUN compound UPS (9)
# 9 UPS NNP PROPN dobj want (6)
# 10 ? . PUNCT punct want (6)
#
# There are some very good reasons.
# ------------------------------------
# 0 There EX PRON expl are (1)
# 1 are VBP AUX ROOT are (1)
# 2 some DT DET det reasons (5)
# 3 very RB ADV advmod good (4)
# 4 good JJ ADJ amod reasons (5)
# 5 reasons NNS NOUN attr are (1)
# 6 . . PUNCT punct are (1)
#
# (1) You never want your machine to go down incorrectly because of a blackout.
# ------------------------------------
# 0 ( -LRB- PUNCT punct 1 (1)
# 1 1 LS X meta want (5)
# 2 ) -RRB- PUNCT punct 1 (1)
# 3 You PRP PRON nsubj want (5)
# 4 never RB ADV neg want (5)
# 5 want VBP VERB ROOT want (5)
# 6 your PRP$ DET poss machine (7)
# 7 machine NN NOUN nsubj go (9)
# 8 to TO PART aux go (9)
# 9 go VB VERB ccomp want (5)
# 10 down RB ADV prt go (9)
# 11 incorrectly RB ADV advmod go (9)
# 12 because IN SCONJ prep go (9)
# 13 of IN ADP pcomp because (12)
# 14 a DT DET det blackout (15)
# 15 blackout NN NOUN pobj because (12)
# 16 . . PUNCT punct want (5)
#
# (2) You want to work with clean power only.
# ------------------------------------
# 0 ( -LRB- PUNCT punct 2 (1)
# 1 2 LS X meta want (4)
# 2 ) -RRB- PUNCT punct 2 (1)
# 3 You PRP PRON nsubj want (4)
# 4 want VBP VERB ROOT want (4)
# 5 to TO PART aux work (6)
# 6 work VB VERB xcomp want (4)
# 7 with IN ADP prep work (6)
# 8 clean JJ ADJ amod power (9)
# 9 power NN NOUN pobj with (7)
# 10 only RB ADV advmod work (6)
# 11 . . PUNCT punct want (4)
#
# (3) You want to monitor your PC power.
# ------------------------------------
# 0 ( -LRB- PUNCT punct 3 (1)
# 1 3 LS X meta want (4)
# 2 ) -RRB- PUNCT punct 3 (1)
# 3 You PRP PRON nsubj want (4)
# 4 want VBP VERB ROOT want (4)
# 5 to TO PART aux monitor (6)
# 6 monitor VB VERB xcomp want (4)
# 7 your PRP$ DET poss power (9)
# 8 PC NN NOUN compound power (9)
# 9 power NN NOUN dobj monitor (6)
# 10 . . PUNCT punct want (4)
#
# (4) You want to prevent your PC from being damaged due to a power problem like a lighting strike and want surge protection.
# ------------------------------------
# 0 ( -LRB- PUNCT punct 4 (1)
# 1 4 LS X meta want (4)
# 2 ) -RRB- PUNCT punct 4 (1)
# 3 You PRP PRON nsubj want (4)
# 4 want VBP VERB ROOT want (4)
# 5 to TO PART aux prevent (6)
# 6 prevent VB VERB xcomp want (4)
# 7 your PRP$ DET poss PC (8)
# 8 PC NN NOUN dobj prevent (6)
# 9 from IN ADP prep prevent (6)
# 10 being VBG AUX auxpass damaged (11)
# 11 damaged VBN VERB pcomp from (9)
# 12 due JJ ADJ prep damaged (11)
# 13 to IN ADP pcomp due (12)
# 14 a DT DET det problem (16)
# 15 power NN NOUN compound problem (16)
# 16 problem NN NOUN pobj due (12)
# 17 like IN SCONJ prep problem (16)
# 18 a DT DET det strike (20)
# 19 lighting NN NOUN compound strike (20)
# 20 strike NN NOUN pobj like (17)
# 21 and CC CCONJ cc damaged (11)
# 22 want VBP VERB conj damaged (11)
# 23 surge NN NOUN compound protection (24)
# 24 protection NN NOUN dobj want (22)
# 25 . . PUNCT punct want (4)
#
# The first rule about UPS is to never trust the insurance claim.
# ------------------------------------
# 0 The DT DET det rule (2)
# 1 first JJ ADJ amod rule (2)
# 2 rule NN NOUN nsubj is (5)
# 3 about IN ADP prep rule (2)
# 4 UPS NNP PROPN pobj about (3)
# 5 is VBZ AUX ROOT is (5)
# 6 to TO PART aux trust (8)
# 7 never RB ADV neg trust (8)
# 8 trust VB VERB xcomp is (5)
# 9 the DT DET det claim (11)
# 10 insurance NN NOUN compound claim (11)
# 11 claim NN NOUN dobj trust (8)
# 12 . . PUNCT punct is (5)
#
# Get your PC insured elsewhere.
# ------------------------------------
# 0 Get VB AUX ROOT Get (0)
# 1 your PRP$ DET poss PC (2)
# 2 PC NN NOUN nsubj insured (3)
# 3 insured VBN VERB ccomp Get (0)
# 4 elsewhere RB ADV advmod insured (3)
# 5 . . PUNCT punct Get (0)
#
# These companies have a tendency not to support their insurance claims.
# ------------------------------------
# 0 These DT DET det companies (1)
# 1 companies NNS NOUN nsubj have (2)
# 2 have VBP AUX ROOT have (2)
# 3 a DT DET det tendency (4)
# 4 tendency NN NOUN dobj have (2)
# 5 not RB PART neg support (7)
# 6 to TO PART aux support (7)
# 7 support VB VERB acl tendency (4)
# 8 their PRP$ DET poss claims (10)
# 9 insurance NN NOUN compound claims (10)
# 10 claims NNS NOUN dobj support (7)
# 11 . . PUNCT punct have (2)
#
# I have a PC running some very high specifications with over six USB devices, LCD monitor, printer and Ethernet equipment, with everything on at the same time.
# ------------------------------------
# 0 I PRP PRON nsubj have (1)
# 1 have VBP AUX ROOT have (1)
# 2 a DT DET det PC (3)
# 3 PC NN NOUN dobj have (1)
# 4 running VBG VERB acl PC (3)
# 5 some DT DET det specifications (8)
# 6 very RB ADV advmod high (7)
# 7 high JJ ADJ amod specifications (8)
# 8 specifications NNS NOUN dobj running (4)
# 9 with IN ADP prep running (4)
# 10 over IN ADP quantmod six (11)
# 11 six CD NUM nummod devices (13)
# 12 USB NN NOUN compound devices (13)
# 13 devices NNS NOUN pobj with (9)
# 14 , , PUNCT punct have (1)
# 15 LCD NN NOUN compound monitor (16)
# 16 monitor NN NOUN npadvmod have (1)
# 17 , , PUNCT punct monitor (16)
# 18 printer NN NOUN conj monitor (16)
# 19 and CC CCONJ cc printer (18)
# 20 Ethernet NN NOUN compound equipment (21)
# 21 equipment NN NOUN conj printer (18)
# 22 , , PUNCT punct monitor (16)
# 23 with IN ADP prep have (1)
# 24 everything NN PRON pobj with (23)
# 25 on RP ADP prep everything (24)
# 26 at IN ADP prep everything (24)
# 27 the DT DET det time (29)
# 28 same JJ ADJ amod time (29)
# 29 time NN NOUN pobj at (26)
# 30 . . PUNCT punct have (1)
#
# I have never gone above 325W of usage and average between 250W and 300W when managing a high spec game and doing lots of background tasks.
# ------------------------------------
# 0 I PRP PRON nsubj gone (3)
# 1 have VBP AUX aux gone (3)
# 2 never RB ADV neg gone (3)
# 3 gone VBN VERB ROOT gone (3)
# 4 above IN ADP prep gone (3)
# 5 325W CD NUM pobj above (4)
# 6 of IN ADP prep 325W (5)
# 7 usage NN NOUN pobj of (6)
# 8 and CC CCONJ cc 325W (5)
# 9 average JJ ADJ conj 325W (5)
# 10 between IN ADP prep average (9)
# 11 250W CD NUM pobj between (10)
# 12 and CC CCONJ cc 250W (11)
# 13 300W CD NUM conj 250W (11)
# 14 when WRB ADV advmod managing (15)
# 15 managing VBG VERB advcl average (9)
# 16 a DT DET det game (19)
# 17 high JJ ADJ amod game (19)
# 18 spec NN NOUN compound game (19)
# 19 game NN NOUN dobj managing (15)
# 20 and CC CCONJ cc managing (15)
# 21 doing VBG VERB conj managing (15)
# 22 lots NNS NOUN dobj doing (21)
# 23 of IN ADP prep lots (22)
# 24 background NN NOUN compound tasks (25)
# 25 tasks NNS NOUN pobj of (23)
# 26 . . PUNCT punct gone (3)
#
# Even though I have a 400W Power Supply Unit (PSU)
# ------------------------------------
# 0 Even RB ADV advmod have (3)
# 1 though IN SCONJ mark have (3)
# 2 I PRP PRON nsubj have (3)
# 3 have VBP AUX ROOT have (3)
# 4 a DT DET det Unit (8)
# 5 400W CD NUM compound Unit (8)
# 6 Power NNP PROPN compound Unit (8)
# 7 Supply NNP PROPN compound Unit (8)
# 8 Unit NNP PROPN dobj have (3)
# 9 ( -LRB- PUNCT punct PSU (10)
# 10 PSU NNP PROPN appos Unit (8)
# 11 ) -RRB- PUNCT punct Unit (8)
#
# I will be upgrading to a 500W PSU because it is better quality model.
# ------------------------------------
# 0 I PRP PRON nsubj upgrading (3)
# 1 will MD VERB aux upgrading (3)
# 2 be VB AUX aux upgrading (3)
# 3 upgrading VBG VERB ROOT upgrading (3)
# 4 to IN ADP prep upgrading (3)
# 5 a DT DET det PSU (7)
# 6 500W CD NUM compound PSU (7)
# 7 PSU NN NOUN pobj to (4)
# 8 because IN SCONJ mark is (10)
# 9 it PRP PRON nsubj is (10)
# 10 is VBZ AUX advcl upgrading (3)
# 11 better JJR ADJ amod model (13)
# 12 quality NN NOUN compound model (13)
# 13 model NN NOUN attr is (10)
# 14 . . PUNCT punct upgrading (3)
#
# The way I can monitor how many Watts I use is with UPS software and hardware.
# ------------------------------------
# 0 The DT DET det way (1)
# 1 way NN NOUN nsubj is (10)
# 2 I PRP PRON nsubj monitor (4)
# 3 can MD VERB aux monitor (4)
# 4 monitor VB VERB relcl way (1)
# 5 how WRB ADV advmod many (6)
# 6 many JJ ADJ amod Watts (7)
# 7 Watts NNP PROPN dobj use (9)
# 8 I PRP PRON nsubj use (9)
# 9 use VBP VERB ccomp monitor (4)
# 10 is VBZ AUX ROOT is (10)
# 11 with IN ADP prep is (10)
# 12 UPS NNP PROPN compound software (13)
# 13 software NN NOUN pobj with (11)
# 14 and CC CCONJ cc software (13)
# 15 hardware NN NOUN conj software (13)
# 16 . . PUNCT punct is (10)
#
# So the question you need to ask is how many watts you will be using.
# ------------------------------------
# 0 So RB ADV advmod is (7)
# 1 the DT DET det question (2)
# 2 question NN NOUN nsubj is (7)
# 3 you PRP PRON nsubj need (4)
# 4 need VBP VERB relcl question (2)
# 5 to TO PART aux ask (6)
# 6 ask VB VERB xcomp need (4)
# 7 is VBZ AUX ROOT is (7)
# 8 how WRB ADV advmod many (9)
# 9 many JJ ADJ amod watts (10)
# 10 watts NNS NOUN dobj using (14)
# 11 you PRP PRON nsubj using (14)
# 12 will MD VERB aux using (14)
# 13 be VB AUX aux using (14)
# 14 using VBG VERB ccomp is (7)
# 15 . . PUNCT punct is (7)
#
# The short answer to this is you don't know until you install the UPS and software that tells you how many watts you use because that appears to be the only way you can monitor your wattage at this time.
# ------------------------------------
# 0 The DT DET det answer (2)
# 1 short JJ ADJ amod answer (2)
# 2 answer NN NOUN nsubj is (5)
# 3 to IN ADP prep answer (2)
# 4 this DT DET pobj to (3)
# 5 is VBZ AUX ROOT is (5)
# 6 you PRP PRON nsubj know (9)
# 7 do VBP AUX aux know (9)
# 8 n't RB PART neg know (9)
# 9 know VB VERB ccomp is (5)
# 10 until IN ADP mark install (12)
# 11 you PRP PRON nsubj install (12)
# 12 install VBP VERB advcl know (9)
# 13 the DT DET det UPS (14)
# 14 UPS NNP PROPN dobj install (12)
# 15 and CC CCONJ cc UPS (14)
# 16 software NN NOUN conj UPS (14)
# 17 that WDT DET nsubj tells (18)
# 18 tells VBZ VERB relcl UPS (14)
# 19 you PRP PRON dobj tells (18)
# 20 how WRB ADV advmod many (21)
# 21 many JJ ADJ amod watts (22)
# 22 watts NNS NOUN dobj use (24)
# 23 you PRP PRON nsubj use (24)
# 24 use VBP VERB ccomp tells (18)
# 25 because IN SCONJ mark appears (27)
# 26 that DT DET nsubj appears (27)
# 27 appears VBZ VERB advcl install (12)
# 28 to TO PART aux be (29)
# 29 be VB AUX xcomp appears (27)
# 30 the DT DET det way (32)
# 31 only JJ ADJ amod way (32)
# 32 way NN NOUN attr be (29)
# 33 you PRP PRON nsubj monitor (35)
# 34 can MD VERB aux monitor (35)
# 35 monitor VB VERB relcl way (32)
# 36 your PRP$ DET poss wattage (37)
# 37 wattage NN NOUN dobj monitor (35)
# 38 at IN ADP prep monitor (35)
# 39 this DT DET det time (40)
# 40 time NN NOUN pobj at (38)
# 41 . . PUNCT punct is (5)
#
# You need to estimate what it is.
# ------------------------------------
# 0 You PRP PRON nsubj need (1)
# 1 need VBP VERB ROOT need (1)
# 2 to TO PART aux estimate (3)
# 3 estimate VB VERB xcomp need (1)
# 4 what WP PRON attr is (6)
# 5 it PRP PRON nsubj is (6)
# 6 is VBZ AUX ccomp estimate (3)
# 7 . . PUNCT punct need (1)
#
# I would say a high-end domestic PC (not a server) would use 300W max if it has one of every device you can think off turned on.
# ------------------------------------
# 0 I PRP PRON nsubj say (2)
# 1 would MD VERB aux say (2)
# 2 say VB VERB ROOT say (2)
# 3 a DT DET det PC (8)
# 4 high JJ ADJ amod end (6)
# 5 - HYPH PUNCT punct end (6)
# 6 end NN NOUN nmod PC (8)
# 7 domestic JJ ADJ amod PC (8)
# 8 PC NN NOUN nsubj use (15)
# 9 ( -LRB- PUNCT punct PC (8)
# 10 not RB PART neg server (12)
# 11 a DT DET det server (12)
# 12 server NN NOUN appos PC (8)
# 13 ) -RRB- PUNCT punct PC (8)
# 14 would MD VERB aux use (15)
# 15 use VB VERB ccomp say (2)
# 16 300W CD NUM nummod max (17)
# 17 max NN NOUN dobj use (15)
# 18 if IN SCONJ mark has (20)
# 19 it PRP PRON nsubj has (20)
# 20 has VBZ AUX advcl use (15)
# 21 one CD NUM nsubj turned (29)
# 22 of IN ADP prep one (21)
# 23 every DT DET det device (24)
# 24 device NN NOUN pobj of (22)
# 25 you PRP PRON nsubj think (27)
# 26 can MD VERB aux think (27)
# 27 think VB VERB relcl device (24)
# 28 off RP ADP prt think (27)
# 29 turned VBD VERB ccomp has (20)
# 30 on RP ADP prt turned (29)
# 31 . . PUNCT punct say (2)
#
# As soon as we add things like another PC, or several printers, or several monitors, then we can start to overload a 325W UPS.
# ------------------------------------
# 0 As RB ADV advmod soon (1)
# 1 soon RB ADV advmod start (21)
# 2 as IN SCONJ mark add (4)
# 3 we PRP PRON nsubj add (4)
# 4 add VBP VERB advcl soon (1)
# 5 things NNS NOUN dobj add (4)
# 6 like IN SCONJ prep things (5)
# 7 another DT DET det PC (8)
# 8 PC NN NOUN pobj like (6)
# 9 , , PUNCT punct PC (8)
# 10 or CC CCONJ cc PC (8)
# 11 several JJ ADJ amod printers (12)
# 12 printers NNS NOUN conj PC (8)
# 13 , , PUNCT punct printers (12)
# 14 or CC CCONJ cc printers (12)
# 15 several JJ ADJ amod monitors (16)
# 16 monitors NNS NOUN conj printers (12)
# 17 , , PUNCT punct start (21)
# 18 then RB ADV advmod start (21)
# 19 we PRP PRON nsubj start (21)
# 20 can MD VERB aux start (21)
# 21 start VB VERB ROOT start (21)
# 22 to TO PART aux overload (23)
# 23 overload VB VERB xcomp start (21)
# 24 a DT DET det UPS (26)
# 25 325W CD NUM nummod UPS (26)
# 26 UPS NNP PROPN dobj overload (23)
# 27 . . PUNCT punct start (21)
#
# This brings us to the first thing we need to learn about any UPS - Overloading and balancing.
# ------------------------------------
# 0 This DT DET nsubj brings (1)
# 1 brings VBZ VERB ROOT brings (1)
# 2 us PRP PRON dobj brings (1)
# 3 to IN ADP prep brings (1)
# 4 the DT DET det thing (6)
# 5 first JJ ADJ amod thing (6)
# 6 thing NN NOUN pobj to (3)
# 7 we PRP PRON nsubj need (8)
# 8 need VBP VERB relcl thing (6)
# 9 to TO PART aux learn (10)
# 10 learn VB VERB xcomp need (8)
# 11 about IN ADP prep learn (10)
# 12 any DT DET det Overloading (15)
# 13 UPS NNP PROPN compound Overloading (15)
# 14 - HYPH PUNCT punct Overloading (15)
# 15 Overloading NN NOUN pobj about (11)
# 16 and CC CCONJ cc Overloading (15)
# 17 balancing VBG VERB conj Overloading (15)
# 18 . . PUNCT punct brings (1)
#
# The overload feature is a warning system that turns on when you have overloaded the UPS capacity.
# ------------------------------------
# 0 The DT DET det feature (2)
# 1 overload NN NOUN compound feature (2)
# 2 feature NN NOUN nsubj is (3)
# 3 is VBZ AUX ROOT is (3)
# 4 a DT DET det system (6)
# 5 warning NN NOUN compound system (6)
# 6 system NN NOUN attr is (3)
# 7 that WDT DET nsubj turns (8)
# 8 turns VBZ VERB relcl system (6)
# 9 on RP ADP prt turns (8)
# 10 when WRB ADV advmod overloaded (13)
# 11 you PRP PRON nsubj overloaded (13)
# 12 have VBP AUX aux overloaded (13)
# 13 overloaded VBN VERB advcl turns (8)
# 14 the DT DET det capacity (16)
# 15 UPS NNP PROPN compound capacity (16)
# 16 capacity NN NOUN dobj overloaded (13)
# 17 . . PUNCT punct is (3)
#
# Overloading does two things.
# ------------------------------------
# 0 Overloading VBG VERB nsubj does (1)
# 1 does VBZ AUX ROOT does (1)
# 2 two CD NUM nummod things (3)
# 3 things NNS NOUN dobj does (1)
# 4 . . PUNCT punct does (1)
#
# It can in theory eventually damage the UPS and it voids the warranty.
# ------------------------------------
# 0 It PRP PRON nsubj damage (5)
# 1 can MD VERB aux damage (5)
# 2 in IN ADP prep damage (5)
# 3 theory NN NOUN pobj in (2)
# 4 eventually RB ADV advmod damage (5)
# 5 damage VB VERB ROOT damage (5)
# 6 the DT DET det UPS (7)
# 7 UPS NNP PROPN dobj damage (5)
# 8 and CC CCONJ cc damage (5)
# 9 it PRP PRON nsubj voids (10)
# 10 voids VBZ VERB conj damage (5)
# 11 the DT DET det warranty (12)
# 12 warranty NN NOUN dobj voids (10)
# 13 . . PUNCT punct voids (10)
#
# Most UPS are 325W
# ------------------------------------
# 0 Most JJS ADJ amod UPS (1)
# 1 UPS NNP PROPN nsubj are (2)
# 2 are VBP AUX ROOT are (2)
# 3 325W CD NUM attr are (2)
#
# but there are 800W - 1000W and even greater models out there for home networks that use more than one PC setup but to be honest
# ------------------------------------
# 0 but CC CCONJ cc are (2)
# 1 there EX PRON expl are (2)
# 2 are VBP AUX ROOT are (2)
# 3 800W CD NUM compound 1000W (5)
# 4 - SYM SYM punct 1000W (5)
# 5 1000W CD NUM attr are (2)
# 6 and CC CCONJ cc 1000W (5)
# 7 even RB ADV advmod greater (8)
# 8 greater JJR ADJ amod models (9)
# 9 models NNS NOUN conj 1000W (5)
# 10 out IN SCONJ advmod there (11)
# 11 there RB ADV advmod models (9)
# 12 for IN ADP prep models (9)
# 13 home NN NOUN compound networks (14)
# 14 networks NNS NOUN pobj for (12)
# 15 that WDT DET nsubj use (16)
# 16 use VBP VERB relcl networks (14)
# 17 more JJR ADJ amod one (19)
# 18 than IN SCONJ quantmod one (19)
# 19 one CD NUM nummod setup (21)
# 20 PC NN NOUN compound setup (21)
# 21 setup NN NOUN dobj use (16)
# 22 but CC CCONJ cc use (16)
# 23 to TO PART aux be (24)
# 24 be VB AUX conj use (16)
# 25 honest JJ ADJ acomp be (24)
#
# you are probably going to get a UPS per PC setup rather than expensive bigger UPS for a network.
# ------------------------------------
# 0 you PRP PRON nsubj going (3)
# 1 are VBP AUX aux going (3)
# 2 probably RB ADV advmod going (3)
# 3 going VBG VERB ROOT going (3)
# 4 to TO PART aux get (5)
# 5 get VB AUX xcomp going (3)
# 6 a DT DET det UPS (7)
# 7 UPS NN NOUN dobj get (5)
# 8 per IN ADP prep UPS (7)
# 9 PC NN NOUN compound setup (10)
# 10 setup NN NOUN pobj per (8)
# 11 rather RB ADV advmod than (12)
# 12 than IN SCONJ cc UPS (7)
# 13 expensive JJ ADJ amod UPS (15)
# 14 bigger JJR ADJ amod UPS (15)
# 15 UPS NNP PROPN pobj than (12)
# 16 for IN ADP prep UPS (15)
# 17 a DT DET det network (18)
# 18 network NN NOUN pobj for (16)
# 19 . . PUNCT punct going (3)
#
# So check the UPS rating.
# ------------------------------------
# 0 So RB ADV advmod check (1)
# 1 check VB VERB ROOT check (1)
# 2 the DT DET det rating (4)
# 3 UPS NNP PROPN compound rating (4)
# 4 rating NN NOUN dobj check (1)
# 5 . . PUNCT punct check (1)
#
# What UPS you choose depends on how much you want to load on it.
# ------------------------------------
# 0 What WP PRON dobj choose (3)
# 1 UPS NNP PROPN aux choose (3)
# 2 you PRP PRON nsubj choose (3)
# 3 choose VBP VERB csubj depends (4)
# 4 depends VBZ VERB ROOT depends (4)
# 5 on IN ADP prep depends (4)
# 6 how WRB ADV advmod much (7)
# 7 much JJ ADJ dobj load (11)
# 8 you PRP PRON nsubj want (9)
# 9 want VBP VERB pcomp on (5)
# 10 to TO PART aux load (11)
# 11 load VB VERB xcomp want (9)
# 12 on IN ADP prep load (11)
# 13 it PRP PRON pobj on (12)
# 14 . . PUNCT punct depends (4)
#
# Next thing you need to check with the UPS is if it comes with a USB connection.
# ------------------------------------
# 0 Next JJ ADJ amod thing (1)
# 1 thing NN NOUN npadvmod need (3)
# 2 you PRP PRON nsubj need (3)
# 3 need VBP VERB csubj is (9)
# 4 to TO PART aux check (5)
# 5 check VB VERB xcomp need (3)
# 6 with IN ADP prep check (5)
# 7 the DT DET det UPS (8)
# 8 UPS NNP PROPN pobj with (6)
# 9 is VBZ AUX ROOT is (9)
# 10 if IN SCONJ mark comes (12)
# 11 it PRP PRON nsubj comes (12)
# 12 comes VBZ VERB advcl is (9)
# 13 with IN ADP prep comes (12)
# 14 a DT DET det connection (16)
# 15 USB NN NOUN compound connection (16)
# 16 connection NN NOUN pobj with (13)
# 17 . . PUNCT punct is (9)
#
# If it does this is a big plus because it means you can control it from your PC and the UPS comes with software.
# ------------------------------------
# 0 If IN SCONJ mark does (2)
# 1 it PRP PRON nsubj does (2)
# 2 does VBZ AUX advcl is (4)
# 3 this DT DET nsubj is (4)
# 4 is VBZ AUX ROOT is (4)
# 5 a DT DET det big (6)
# 6 big JJ ADJ amod plus (7)
# 7 plus NN NOUN attr is (4)
# 8 because IN SCONJ mark means (10)
# 9 it PRP PRON nsubj means (10)
# 10 means VBZ VERB advcl is (4)
# 11 you PRP PRON nsubj control (13)
# 12 can MD VERB aux control (13)
# 13 control VB VERB ccomp means (10)
# 14 it PRP PRON dobj control (13)
# 15 from IN ADP prep control (13)
# 16 your PRP$ DET poss PC (17)
# 17 PC NN NOUN pobj from (15)
# 18 and CC CCONJ cc control (13)
# 19 the DT DET det UPS (20)
# 20 UPS NNP PROPN nsubj comes (21)
# 21 comes VBZ VERB conj control (13)
# 22 with IN ADP prep comes (21)
# 23 software NN NOUN pobj with (22)
# 24 . . PUNCT punct is (4)
#
# Now if the UPS has this feature then you can do loads of stuff like turning off UPS sound alarms, controlling how your UPS handles a blackout, how long it uses the battery before shutdown or hibernation, if it sounds an alarm or not, if it run self tests, data collection and monitoring, notifications and sensitivity settings.
# ------------------------------------
# 0 Now RB ADV advmod do (10)
# 1 if IN SCONJ mark has (4)
# 2 the DT DET det UPS (3)
# 3 UPS NNP PROPN nsubj has (4)
# 4 has VBZ AUX advcl do (10)
# 5 this DT DET det feature (6)
# 6 feature NN NOUN dobj has (4)
# 7 then RB ADV advmod do (10)
# 8 you PRP PRON nsubj do (10)
# 9 can MD VERB aux do (10)
# 10 do VB AUX advcl uses (32)
# 11 loads NNS NOUN dobj do (10)
# 12 of IN ADP prep loads (11)
# 13 stuff NN NOUN pobj of (12)
# 14 like IN SCONJ prep stuff (13)
# 15 turning VBG VERB pcomp like (14)
# 16 off RP ADP prt turning (15)
# 17 UPS NNP PROPN compound alarms (19)
# 18 sound NN NOUN amod alarms (19)
# 19 alarms NNS NOUN dobj turning (15)
# 20 , , PUNCT punct do (10)
# 21 controlling VBG VERB advcl do (10)
# 22 how WRB ADV advmod handles (25)
# 23 your PRP$ DET poss UPS (24)
# 24 UPS NNP PROPN nsubj handles (25)
# 25 handles VBZ VERB ccomp controlling (21)
# 26 a DT DET det blackout (27)
# 27 blackout NN NOUN dobj handles (25)
# 28 , , PUNCT punct uses (32)
# 29 how WRB ADV advmod long (30)
# 30 long RB ADV advmod uses (32)
# 31 it PRP PRON nsubj uses (32)
# 32 uses VBZ VERB ROOT uses (32)
# 33 the DT DET det battery (34)
# 34 battery NN NOUN dobj uses (32)
# 35 before IN ADP prep battery (34)
# 36 shutdown NN NOUN pobj before (35)
# 37 or CC CCONJ cc shutdown (36)
# 38 hibernation NN NOUN conj shutdown (36)
# 39 , , PUNCT punct uses (32)
# 40 if IN SCONJ mark sounds (42)
# 41 it PRP PRON nsubj sounds (42)
# 42 sounds VBZ VERB advcl uses (32)
# 43 an DT DET det alarm (44)
# 44 alarm NN NOUN dobj sounds (42)
# 45 or CC CCONJ cc sounds (42)
# 46 not RB PART conj sounds (42)
# 47 , , PUNCT punct sounds (42)
# 48 if IN SCONJ mark run (50)
# 49 it PRP PRON nsubj run (50)
# 50 run VBP VERB advcl sounds (42)
# 51 self NN NOUN compound tests (52)
# 52 tests NNS NOUN dobj run (50)
# 53 , , PUNCT punct tests (52)
# 54 data NNS NOUN compound collection (55)
# 55 collection NN NOUN conj tests (52)
# 56 and CC CCONJ cc collection (55)
# 57 monitoring NN NOUN conj collection (55)
# 58 , , PUNCT punct monitoring (57)
# 59 notifications NNS NOUN conj monitoring (57)
# 60 and CC CCONJ cc notifications (59)
# 61 sensitivity NN NOUN compound settings (62)
# 62 settings NNS NOUN conj notifications (59)
# 63 . . PUNCT punct uses (32)
#
# If the UPS does not come with a USB connection and software then you probably should be looking for an UPS designed for computer use rather than a UPS for non-computer equipment.
# ------------------------------------
# 0 If IN SCONJ mark come (5)
# 1 the DT DET det UPS (2)
# 2 UPS NNP PROPN nsubj come (5)
# 3 does VBZ AUX aux come (5)
# 4 not RB PART neg come (5)
# 5 come VB VERB advcl looking (17)
# 6 with IN ADP prep come (5)
# 7 a DT DET det connection (9)
# 8 USB NN NOUN compound connection (9)
# 9 connection NN NOUN pobj with (6)
# 10 and CC CCONJ cc connection (9)
# 11 software NN NOUN conj connection (9)
# 12 then RB ADV advmod looking (17)
# 13 you PRP PRON nsubj looking (17)
# 14 probably RB ADV advmod looking (17)
# 15 should MD VERB aux looking (17)
# 16 be VB AUX aux looking (17)
# 17 looking VBG VERB ROOT looking (17)
# 18 for IN ADP prep looking (17)
# 19 an DT DET det UPS (20)
# 20 UPS NNP PROPN pobj for (18)
# 21 designed VBN VERB acl UPS (20)
# 22 for IN ADP prep designed (21)
# 23 computer NN NOUN compound use (24)
# 24 use NN NOUN pobj for (22)
# 25 rather RB ADV advmod than (26)
# 26 than IN SCONJ cc use (24)
# 27 a DT DET det UPS (28)
# 28 UPS NNP PROPN conj use (24)
# 29 for IN ADP prep UPS (28)
# 30 non JJ ADJ dep - (31)
# 31 - JJ ADJ dep computer (32)
# 32 computer JJ ADJ amod equipment (33)
# 33 equipment NN NOUN pobj for (29)
# 34 . . PUNCT punct looking (17)
#
# Most UPS have LED indicators that tell you the status of the unit.
# ------------------------------------
# 0 Most JJS ADJ amod UPS (1)
# 1 UPS NNS NOUN nsubj have (2)
# 2 have VBP AUX ROOT have (2)
# 3 LED VBN VERB compound indicators (4)
# 4 indicators NNS NOUN dobj have (2)
# 5 that WDT DET nsubj tell (6)
# 6 tell VBP VERB relcl indicators (4)
# 7 you PRP PRON dative tell (6)
# 8 the DT DET det status (9)
# 9 status NN NOUN dobj tell (6)
# 10 of IN ADP prep status (9)
# 11 the DT DET det unit (12)
# 12 unit NN NOUN pobj of (10)
# 13 . . PUNCT punct have (2)
#
# The next thing to understand is that testing your UPS is not done by breaking it out of the box, connecting it to the mains, plugging your PC in and then turning off the house's power with the circuit breaker.
# ------------------------------------
# 0 The DT DET det thing (2)
# 1 next JJ ADJ amod thing (2)
# 2 thing NN NOUN nsubj is (5)
# 3 to TO PART aux understand (4)
# 4 understand VB VERB relcl thing (2)
# 5 is VBZ AUX ROOT is (5)
# 6 that IN SCONJ mark done (12)
# 7 testing VBG VERB csubjpass done (12)
# 8 your PRP$ DET poss UPS (9)
# 9 UPS NNP PROPN dobj testing (7)
# 10 is VBZ AUX auxpass done (12)
# 11 not RB PART neg done (12)
# 12 done VBN VERB ccomp is (5)
# 13 by IN ADP prep done (12)
# 14 breaking VBG VERB pcomp by (13)
# 15 it PRP PRON dobj breaking (14)
# 16 out IN SCONJ prep breaking (14)
# 17 of IN ADP prep out (16)
# 18 the DT DET det box (19)
# 19 box NN NOUN pobj of (17)
# 20 , , PUNCT punct breaking (14)
# 21 connecting VBG VERB advcl breaking (14)
# 22 it PRP PRON dobj connecting (21)
# 23 to IN ADP prep connecting (21)
# 24 the DT DET det mains (25)
# 25 mains NNS NOUN pobj to (23)
# 26 , , PUNCT punct breaking (14)
# 27 plugging VBG VERB advcl breaking (14)
# 28 your PRP$ DET poss PC (29)
# 29 PC NN NOUN dobj plugging (27)
# 30 in IN ADP advmod plugging (27)
# 31 and CC CCONJ cc plugging (27)
# 32 then RB ADV advmod turning (33)
# 33 turning VBG VERB conj plugging (27)
# 34 off RP ADP prt turning (33)
# 35 the DT DET det house (36)
# 36 house NN NOUN poss power (38)
# 37 's POS PART case house (36)
# 38 power NN NOUN dobj turning (33)
# 39 with IN ADP prep turning (33)
# 40 the DT DET det breaker (42)
# 41 circuit NN NOUN compound breaker (42)
# 42 breaker NN NOUN pobj with (39)
# 43 . . PUNCT punct is (5)
#
# You must charge the UPS first!
# ------------------------------------
# 0 You PRP PRON nsubj charge (2)
# 1 must MD VERB aux charge (2)
# 2 charge VB VERB ROOT charge (2)
# 3 the DT DET det UPS (4)
# 4 UPS NNP PROPN dobj charge (2)
# 5 first RB ADV advmod charge (2)
# 6 ! . PUNCT punct charge (2)
#
# So read the instructions.
# ------------------------------------
# 0 So RB ADV advmod read (1)
# 1 read VB VERB ROOT read (1)
# 2 the DT DET det instructions (3)
# 3 instructions NNS NOUN dobj read (1)
# 4 . . PUNCT punct read (1)
#
# Usually you must attach the battery to the UPS (plug it in firmly!) and wait before using it.
# ------------------------------------
# 0 Usually RB ADV advmod attach (3)
# 1 you PRP PRON nsubj attach (3)
# 2 must MD VERB aux attach (3)
# 3 attach VB VERB ROOT attach (3)
# 4 the DT DET det battery (5)
# 5 battery NN NOUN dobj attach (3)
# 6 to IN ADP prep attach (3)
# 7 the DT DET det UPS (8)
# 8 UPS NNP PROPN pobj to (6)
# 9 ( -LRB- PUNCT punct plug (10)
# 10 plug VB VERB parataxis attach (3)
# 11 it PRP PRON dobj plug (10)
# 12 in RP ADP prt plug (10)
# 13 firmly RB ADV advmod plug (10)
# 14 ! . PUNCT punct attach (3)
# 15 ) -RRB- PUNCT punct attach (3)
# 16 and CC CCONJ cc attach (3)
# 17 wait VB VERB conj attach (3)
# 18 before IN ADP prep wait (17)
# 19 using VBG VERB pcomp before (18)
# 20 it PRP PRON dobj using (19)
# 21 . . PUNCT punct attach (3)
#
# Then perform the test using the software first!
# ------------------------------------
# 0 Then RB ADV advmod perform (1)
# 1 perform VB VERB ROOT perform (1)
# 2 the DT DET det test (3)
# 3 test NN NOUN dobj perform (1)
# 4 using VBG VERB advcl perform (1)
# 5 the DT DET det software (6)
# 6 software NN NOUN dobj using (4)
# 7 first RB ADV advmod using (4)
# 8 ! . PUNCT punct perform (1)
#
# Then you can consider trying to simulate a blackout in your home to see if the PC stays up.
# ------------------------------------
# 0 Then RB ADV advmod consider (3)
# 1 you PRP PRON nsubj consider (3)
# 2 can MD VERB aux consider (3)
# 3 consider VB VERB ROOT consider (3)
# 4 trying VBG VERB xcomp consider (3)
# 5 to TO PART aux simulate (6)
# 6 simulate VB VERB xcomp trying (4)
# 7 a DT DET det blackout (8)
# 8 blackout NN NOUN dobj simulate (6)
# 9 in IN ADP prep simulate (6)
# 10 your PRP$ DET poss home (11)
# 11 home NN NOUN pobj in (9)
# 12 to TO PART aux see (13)
# 13 see VB VERB advcl simulate (6)
# 14 if IN SCONJ mark stays (17)
# 15 the DT DET det PC (16)
# 16 PC NN NOUN nsubj stays (17)
# 17 stays VBZ VERB ccomp see (13)
# 18 up RP ADP prt stays (17)
# 19 . . PUNCT punct consider (3)
#
# Usually a UPS is programmed to shutdown your PC if the blackout lasts for a few seconds.
# ------------------------------------
# 0 Usually RB ADV advmod programmed (4)
# 1 a DT DET det UPS (2)
# 2 UPS NNP PROPN nsubjpass programmed (4)
# 3 is VBZ AUX auxpass programmed (4)
# 4 programmed VBN VERB ROOT programmed (4)
# 5 to TO PART aux shutdown (6)
# 6 shutdown VB VERB xcomp programmed (4)
# 7 your PRP$ DET poss PC (8)
# 8 PC NN NOUN dobj shutdown (6)
# 9 if IN SCONJ mark lasts (12)
# 10 the DT DET det blackout (11)
# 11 blackout NN NOUN nsubj lasts (12)
# 12 lasts VBZ VERB advcl shutdown (6)
# 13 for IN ADP prep lasts (12)
# 14 a DT DET det seconds (16)
# 15 few JJ ADJ amod seconds (16)
# 16 seconds NNS NOUN pobj for (13)
# 17 . . PUNCT punct programmed (4)
#
# Nearly all UPS models with a USB connection can be customized for the shutdown event or how long the PC should hold for on the UPS battery.
# ------------------------------------
# 0 Nearly RB ADV advmod all (1)
# 1 all DT DET det models (3)
# 2 UPS NNP PROPN compound models (3)
# 3 models NNS NOUN nsubjpass customized (10)
# 4 with IN ADP prep models (3)
# 5 a DT DET det connection (7)
# 6 USB NN NOUN compound connection (7)
# 7 connection NN NOUN pobj with (4)
# 8 can MD VERB aux customized (10)
# 9 be VB AUX auxpass customized (10)
# 10 customized VBN VERB ROOT customized (10)
# 11 for IN ADP prep customized (10)
# 12 the DT DET det event (14)
# 13 shutdown NN NOUN compound event (14)
# 14 event NN NOUN pobj for (11)
# 15 or CC CCONJ cc customized (10)
# 16 how WRB ADV advmod long (17)
# 17 long JJ ADJ pobj for (22)
# 18 the DT DET det PC (19)
# 19 PC NN NOUN nsubj hold (21)
# 20 should MD VERB aux hold (21)
# 21 hold VB VERB conj customized (10)
# 22 for RP ADP prep hold (21)
# 23 on IN ADP prep hold (21)
# 24 the DT DET det battery (26)
# 25 UPS NNP PROPN compound battery (26)
# 26 battery NN NOUN pobj on (23)
# 27 . . PUNCT punct hold (21)
#
# Most UPS devices allow you to connect a modem phone line into the device and then run a phone line into your modem.
# ------------------------------------
# 0 Most JJS ADJ amod devices (2)
# 1 UPS NNP PROPN compound devices (2)
# 2 devices NNS NOUN nsubj allow (3)
# 3 allow VBP VERB ROOT allow (3)
# 4 you PRP PRON nsubj connect (6)
# 5 to TO PART aux connect (6)
# 6 connect VB VERB ccomp allow (3)
# 7 a DT DET det line (10)
# 8 modem NN NOUN compound line (10)
# 9 phone NN NOUN compound line (10)
# 10 line NN NOUN dobj connect (6)
# 11 into IN ADP prep connect (6)
# 12 the DT DET det device (13)
# 13 device NN NOUN pobj into (11)
# 14 and CC CCONJ cc connect (6)
# 15 then RB ADV advmod run (16)
# 16 run VB VERB conj connect (6)
# 17 a DT DET det line (19)
# 18 phone NN NOUN compound line (19)
# 19 line NN NOUN dobj run (16)
# 20 into IN ADP prep run (16)
# 21 your PRP$ DET poss modem (22)
# 22 modem NN NOUN pobj into (20)
# 23 . . PUNCT punct allow (3)
#
# This is important because power surges on a UPS that do not have this protection can damage a PC through the unprotected phone line running into the modem that usually runs to the PC somehow.
# ------------------------------------
# 0 This DT DET nsubj is (1)
# 1 is VBZ AUX ROOT is (1)
# 2 important JJ ADJ acomp is (1)
# 3 because IN SCONJ mark surges (5)
# 4 power NN NOUN nsubj surges (5)
# 5 surges NNS NOUN advcl is (1)
# 6 on IN ADP prep surges (5)
# 7 a DT DET det UPS (8)
# 8 UPS NNP PROPN pobj on (6)
# 9 that WDT DET nsubj have (12)
# 10 do VBP AUX aux have (12)
# 11 not RB PART neg have (12)
# 12 have VB AUX relcl UPS (8)
# 13 this DT DET det protection (14)
# 14 protection NN NOUN nsubj damage (16)
# 15 can MD VERB aux damage (16)
# 16 damage VB VERB ccomp have (12)
# 17 a DT DET det PC (18)
# 18 PC NN NOUN dobj damage (16)
# 19 through IN ADP prep damage (16)
# 20 the DT DET det line (23)
# 21 unprotected JJ ADJ amod line (23)
# 22 phone NN NOUN compound line (23)
# 23 line NN NOUN pobj through (19)
# 24 running VBG VERB acl line (23)
# 25 into IN ADP prep running (24)
# 26 the DT DET det modem (27)
# 27 modem NN NOUN pobj into (25)
# 28 that WDT DET nsubj runs (30)
# 29 usually RB ADV advmod runs (30)
# 30 runs VBZ VERB relcl modem (27)
# 31 to IN ADP prep runs (30)
# 32 the DT DET det PC (33)
# 33 PC NN NOUN pobj to (31)
# 34 somehow RB ADV advmod runs (30)
# 35 . . PUNCT punct is (1)
#
# This is nasty problem with the degree of security that a UPS can provide.
# ------------------------------------
# 0 This DT DET nsubj is (1)
# 1 is VBZ AUX ROOT is (1)
# 2 nasty JJ ADJ amod problem (3)
# 3 problem NN NOUN attr is (1)
# 4 with IN ADP prep problem (3)
# 5 the DT DET det degree (6)
# 6 degree NN NOUN pobj with (4)
# 7 of IN ADP prep degree (6)
# 8 security NN NOUN pobj of (7)
# 9 that WDT DET dobj provide (13)
# 10 a DT DET det UPS (11)
# 11 UPS NNP PROPN nsubj provide (13)
# 12 can MD VERB aux provide (13)
# 13 provide VB VERB relcl degree (6)
# 14 . . PUNCT punct is (1)
#
# If it doesn't have this function then it is not going to provide 100% surge protection with a PC that is on-line.
# ------------------------------------
# 0 If IN SCONJ mark have (4)
# 1 it PRP PRON nsubj have (4)
# 2 does VBZ AUX aux have (4)
# 3 n't RB PART neg have (4)
# 4 have VB AUX advcl going (11)
# 5 this DT DET det function (6)
# 6 function NN NOUN dobj have (4)
# 7 then RB ADV advmod going (11)
# 8 it PRP PRON nsubj going (11)
# 9 is VBZ AUX aux going (11)
# 10 not RB PART neg going (11)
# 11 going VBG VERB ROOT going (11)
# 12 to TO PART aux provide (13)
# 13 provide VB VERB xcomp going (11)
# 14 100 CD NUM nummod % (15)
# 15 % NN NOUN compound protection (17)
# 16 surge NN NOUN compound protection (17)
# 17 protection NN NOUN dobj provide (13)
# 18 with IN ADP prep protection (17)
# 19 a DT DET det PC (20)
# 20 PC NN NOUN pobj with (18)
# 21 that WDT DET nsubj is (22)
# 22 is VBZ AUX relcl PC (20)
# 23 on IN ADP prep is (22)
# 24 - HYPH PUNCT punct on (23)
# 25 line NN NOUN pobj on (23)
# 26 . . PUNCT punct going (11)
#
# Networking a UPS PC to another PC without UPS can also increase the risk of surge protection problems.
# ------------------------------------
# 0 Networking VBG VERB csubj increase (11)
# 1 a DT DET det PC (3)
# 2 UPS NNP PROPN compound PC (3)
# 3 PC NN NOUN dobj Networking (0)
# 4 to IN ADP prep Networking (0)
# 5 another DT DET det PC (6)
# 6 PC NN NOUN pobj to (4)
# 7 without IN ADP prep Networking (0)
# 8 UPS NNP PROPN pobj without (7)
# 9 can MD VERB aux increase (11)
# 10 also RB ADV advmod increase (11)
# 11 increase VB VERB ROOT increase (11)
# 12 the DT DET det risk (13)
# 13 risk NN NOUN dobj increase (11)
# 14 of IN ADP prep risk (13)
# 15 surge NN NOUN compound problems (17)
# 16 protection NN NOUN compound problems (17)
# 17 problems NNS NOUN pobj of (14)
# 18 . . PUNCT punct increase (11)
#
# It is not recommend that you network a UPS PC to a non-UPS PC unless surge protection and the warranty are not an issue.
# ------------------------------------
# 0 It PRP PRON nsubjpass recommend (3)
# 1 is VBZ AUX auxpass recommend (3)
# 2 not RB PART neg recommend (3)
# 3 recommend VB VERB ROOT recommend (3)
# 4 that IN SCONJ mark network (6)
# 5 you PRP PRON nsubj network (6)
# 6 network VBP VERB ccomp recommend (3)
# 7 a DT DET det PC (9)
# 8 UPS NNP PROPN compound PC (9)
# 9 PC NN NOUN dobj network (6)
# 10 to IN ADP prep network (6)
# 11 a DT DET det PC (15)
# 12 non JJ ADJ dep - (13)
# 13 - JJ ADJ dep UPS (14)
# 14 UPS JJ ADJ amod PC (15)
# 15 PC NN NOUN pobj to (10)
# 16 unless IN SCONJ mark are (22)
# 17 surge NN NOUN compound protection (18)
# 18 protection NN NOUN nsubj are (22)
# 19 and CC CCONJ cc protection (18)
# 20 the DT DET det warranty (21)
# 21 warranty NN NOUN conj protection (18)
# 22 are VBP AUX advcl network (6)
# 23 not RB PART neg are (22)
# 24 an DT DET det issue (25)
# 25 issue NN NOUN attr are (22)
# 26 . . PUNCT punct recommend (3)
#
# One last thing is that some UPS have input regions on the UPS for surge protection and other input regions are not surge protected.
# ------------------------------------
# 0 One CD NUM nummod thing (2)
# 1 last JJ ADJ amod thing (2)
# 2 thing NN NOUN nsubj is (3)
# 3 is VBZ AUX ROOT is (3)
# 4 that IN SCONJ mark have (7)
# 5 some DT DET det UPS (6)
# 6 UPS NNS NOUN nsubj have (7)
# 7 have VBP AUX ccomp is (3)
# 8 input NN NOUN compound regions (9)
# 9 regions NNS NOUN nsubjpass protected (23)
# 10 on IN ADP prep regions (9)
# 11 the DT DET det UPS (12)
# 12 UPS NNP PROPN pobj on (10)
# 13 for IN ADP prep regions (9)
# 14 surge NN NOUN compound protection (15)
# 15 protection NN NOUN pobj for (13)
# 16 and CC CCONJ cc protection (15)
# 17 other JJ ADJ amod regions (19)
# 18 input NN NOUN compound regions (19)
# 19 regions NNS NOUN conj protection (15)
# 20 are VBP AUX auxpass protected (23)
# 21 not RB PART neg are (20)
# 22 surge NN NOUN acomp are (20)
# 23 protected VBN VERB ccomp have (7)
# 24 . . PUNCT punct is (3)
#
# Also with some models the batteries need to be replaced after a few years if you end up using them a lot.
# ------------------------------------
# 0 Also RB ADV advmod need (6)
# 1 with IN ADP prep need (6)
# 2 some DT DET det models (3)
# 3 models NNS NOUN pobj with (1)
# 4 the DT DET det batteries (5)
# 5 batteries NNS NOUN nsubj need (6)
# 6 need VBP VERB ROOT need (6)
# 7 to TO PART aux replaced (9)
# 8 be VB AUX auxpass replaced (9)
# 9 replaced VBN VERB xcomp need (6)
# 10 after IN ADP prep replaced (9)
# 11 a DT DET det years (13)
# 12 few JJ ADJ amod years (13)
# 13 years NNS NOUN pobj after (10)
# 14 if IN SCONJ mark end (16)
# 15 you PRP PRON nsubj end (16)
# 16 end VBP VERB advcl need (6)
# 17 up RP ADP prt end (16)
# 18 using VBG VERB xcomp end (16)
# 19 them PRP PRON dobj using (18)
# 20 a DT DET det lot (21)
# 21 lot NN NOUN npadvmod using (18)
# 22 . . PUNCT punct need (6)
#
# This is everything you need to know about an UPS before you choose one.
# ------------------------------------
# 0 This DT DET nsubj is (1)
# 1 is VBZ AUX ROOT is (1)
# 2 everything NN PRON attr is (1)
# 3 you PRP PRON nsubj need (4)
# 4 need VBP VERB relcl everything (2)
# 5 to TO PART aux know (6)
# 6 know VB VERB xcomp need (4)
# 7 about IN ADP prep know (6)
# 8 an DT DET det UPS (9)
# 9 UPS NNP PROPN pobj about (7)
# 10 before IN ADP mark choose (12)
# 11 you PRP PRON nsubj choose (12)
# 12 choose VBP VERB advcl know (6)
# 13 one CD NUM dobj choose (12)
# 14 . . PUNCT punct is (1)
#
# It is basically now about downloading the technical specs of the UPS and making sure it provides you with what you need.
# ------------------------------------
# 0 It PRP PRON nsubj is (1)
# 1 is VBZ AUX ROOT is (1)
# 2 basically RB ADV advmod is (1)
# 3 now RB ADV advmod is (1)
# 4 about IN ADP prep is (1)
# 5 downloading VBG VERB pcomp about (4)
# 6 the DT DET det specs (8)
# 7 technical JJ ADJ amod specs (8)
# 8 specs NNS NOUN dobj downloading (5)
# 9 of IN ADP prep specs (8)
# 10 the DT DET det UPS (11)
# 11 UPS NNP PROPN pobj of (9)
# 12 and CC CCONJ cc downloading (5)
# 13 making VBG VERB conj downloading (5)
# 14 sure JJ ADJ acomp making (13)
# 15 it PRP PRON nsubj provides (16)
# 16 provides VBZ VERB ccomp sure (14)
# 17 you PRP PRON dobj provides (16)
# 18 with IN ADP prep provides (16)
# 19 what WP PRON dobj need (21)
# 20 you PRP PRON nsubj need (21)
# 21 need VBP VERB pcomp with (18)
# 22 . . PUNCT punct is (1)
#
# The two top brands are APC and Belkin
# ------------------------------------
# 0 The DT DET det brands (3)
# 1 two CD NUM nummod brands (3)
# 2 top JJ ADJ amod brands (3)
# 3 brands NNS NOUN nsubj are (4)
# 4 are VBP AUX ROOT are (4)
# 5 APC NNP PROPN attr are (4)
# 6 and CC CCONJ cc APC (5)
# 7 Belkin NNP PROPN conj APC (5)
#
# We bought this to backup the iMac G5 that I got my wife for Christmas.
# ------------------------------------
# 0 We PRP PRON nsubj bought (1)
# 1 bought VBD VERB ROOT bought (1)
# 2 this DT DET dobj bought (1)
# 3 to TO PART aux backup (4)
# 4 backup VB VERB advcl bought (1)
# 5 the DT DET det G5 (7)
# 6 iMac NNP PROPN compound G5 (7)
# 7 G5 NN NOUN dobj backup (4)
# 8 that WDT DET mark got (10)
# 9 I PRP PRON nsubj got (10)
# 10 got VBD VERB ccomp backup (4)
# 11 my PRP$ DET poss wife (12)
# 12 wife NN NOUN dobj got (10)
# 13 for IN ADP prep got (10)
# 14 Christmas NNP PROPN pobj for (13)
# 15 . . PUNCT punct bought (1)
#
# I have had an APC since 1996 and have depended on it to keep my systems running smoothly with the typical voltage fluctuations that we have in our area.
# ------------------------------------
# 0 I PRP PRON nsubj had (2)
# 1 have VBP AUX aux had (2)
# 2 had VBN VERB ROOT had (2)
# 3 an DT DET det APC (4)
# 4 APC NNP PROPN dobj had (2)
# 5 since IN SCONJ prep had (2)
# 6 1996 CD NUM pobj since (5)
# 7 and CC CCONJ cc had (2)
# 8 have VBP AUX aux depended (9)
# 9 depended VBN VERB conj had (2)
# 10 on IN ADP prep depended (9)
# 11 it PRP PRON pobj on (10)
# 12 to TO PART aux keep (13)
# 13 keep VB VERB advcl depended (9)
# 14 my PRP$ DET poss systems (15)
# 15 systems NNS NOUN dobj keep (13)
# 16 running VBG VERB xcomp keep (13)
# 17 smoothly RB ADV advmod running (16)
# 18 with IN ADP prep running (16)
# 19 the DT DET det fluctuations (22)
# 20 typical JJ ADJ amod fluctuations (22)
# 21 voltage NN NOUN compound fluctuations (22)
# 22 fluctuations NNS NOUN pobj with (18)
# 23 that WDT DET dobj have (25)
# 24 we PRP PRON nsubj have (25)
# 25 have VBP AUX relcl fluctuations (22)
# 26 in IN ADP prep have (25)
# 27 our PRP$ DET poss area (28)
# 28 area NN NOUN pobj in (26)
# 29 . . PUNCT punct had (2)
#
# The overall product is very well designed and is a good value for the money.
# ------------------------------------
# 0 The DT DET det product (2)
# 1 overall JJ ADJ amod product (2)
# 2 product NN NOUN nsubj is (3)
# 3 is VBZ AUX ROOT is (3)
# 4 very RB ADV advmod well (5)
# 5 well RB ADV advmod designed (6)
# 6 designed VBN VERB acomp is (3)
# 7 and CC CCONJ cc is (3)
# 8 is VBZ AUX conj is (3)
# 9 a DT DET det value (11)
# 10 good JJ ADJ amod value (11)
# 11 value NN NOUN attr is (8)
# 12 for IN ADP prep value (11)
# 13 the DT DET det money (14)
# 14 money NN NOUN pobj for (12)
# 15 . . PUNCT punct is (3)
#
# I'm not sure if the Powerchute software was updated to run on Mac Tiger, howvever, so I did not install it.
# ------------------------------------
# 0 I PRP PRON nsubj 'm (1)
# 1 'm VBP AUX ROOT 'm (1)
# 2 not RB PART neg 'm (1)
# 3 sure JJ ADJ acomp 'm (1)
# 4 if IN SCONJ mark updated (9)
# 5 the DT DET det software (7)
# 6 Powerchute NNP PROPN compound software (7)
# 7 software NN NOUN nsubjpass updated (9)
# 8 was VBD AUX auxpass updated (9)
# 9 updated VBN VERB advcl 'm (1)
# 10 to TO PART aux run (11)
# 11 run VB VERB xcomp updated (9)
# 12 on IN ADP prep run (11)
# 13 Mac NNP PROPN compound Tiger (14)
# 14 Tiger NNP PROPN pobj on (12)
# 15 , , PUNCT punct Tiger (14)
# 16 howvever NN NOUN appos Tiger (14)
# 17 , , PUNCT punct 'm (1)
# 18 so CC CCONJ cc 'm (1)
# 19 I PRP PRON nsubj install (22)
# 20 did VBD AUX aux install (22)
# 21 not RB PART neg install (22)
# 22 install VB VERB conj 'm (1)
# 23 it PRP PRON dobj install (22)
# 24 . . PUNCT punct install (22)
#
# Steve Reis
# ------------------------------------
# 0 Steve NNP PROPN compound Reis (1)
# 1 Reis NNP PROPN ROOT Reis (1)

# %%
# displacy sublibrary part of SpaCy lets us visualize the dependency parse of a sentence
import spacy
from spacy import displacy

sentence = "These companies have a tendency not to support their insurance claims."
sent = nlp(sentence)
displacy.serve(sent, style = "dep")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\spacy\displacy\__init__.py:94: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e8253c5ad25e4bd589b66b8ac7ec8ab5-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">These</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">companies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">tendency</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">support</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">their</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">insurance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">claims.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-2" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-3" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,266.5 L753.0,254.5 737.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-4" stroke-width="2px" d="M945,264.5 C945,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">neg</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-6" stroke-width="2px" d="M770,264.5 C770,2.0 1275.0,2.0 1275.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,266.5 L1283.0,254.5 1267.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-7" stroke-width="2px" d="M1470,264.5 C1470,89.5 1795.0,89.5 1795.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e8253c5ad25e4bd589b66b8ac7ec8ab5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ##Task: Given a concept (word), find the K (parameter) most frequent adjectives
# that appear with that noun (i.e., directly describe that noun) in the corpus of Amazon
# reviews (file: unlabeled_reviews.txt in the data subdirectory of the tutorials)
#
# ##Assignment: The concept (word) selected is 'PC'. In other words, search for patterns "[ADJ] PC" -- i.e., where "ADJ" precedes the token with the lemma "PC"

# %%
nlp.add_pipe(nlp.create_pipe('sentencizer'))

# %%
# if we're not using dependency parsing (which in case we won't) we need to add an explicit sentence splitter to the Spacy pipeline
#nlp.add_pipe(nlp.create_pipe('sentencizer'))

# solution
aspects = []


for doc in nlp.pipe(dataset, disable=["parser", "ner"]):
    for sent in doc.sents:
        for tok in sent:
            # if the lemma of the token is "PC"
            if tok.lemma_ == "PC":
                # and it is not the first token in the sentence and the preceeding token has POS-tag "JJ" or "NN"
                if (tok.i - sent.start > 0) and doc[tok.i - 1].pos_ in ["ADJ"]:
                    print(sent.text)
                    print("-----------------")
                    asp = doc[tok.i - 1].text
                    print(asp)
                    print()
                    
                    aspects.append(asp)

unique_aspect_words = set(aspects)
print([uas + "PC" for uas in unique_aspect_words])
# Out:
# Delorme has a product that is not even compatible with the present PC Handheld operating system.
# -----------------
# present
#
# The other is, that the antenna cable for the wireless PC Card needs to be longer to more easily place the antenna on my computer's furniture cabinet
# -----------------
# wireless
#
# Newer PC's (if you build your own) seem to all have this port already built in to the motherboard.
# -----------------
# Newer
#
# I needed a USB cord for new PC/Printer installations.
# -----------------
# new
#
# Besides, according to a recent PC Magazine review, a number of no-brand keyboards usually sold by chains like CompUSA actually sport very good quality at very low prices, so this might be another route for a conscious keyboard shopper
# -----------------
# recent
#
# My $150 (I think I paid more over the summer) Sony recorder now sits in my bag and I only use the $79.99 "Olympus Digital Voice Recorder with Direct PC Link".
# -----------------
# Direct
#
# Many cheap under designed amplified PC speakers act as pesty detectors of any RF energy (including actual legal transmited signals) in the presence of RF fields such as in the vecinity of legal Ham radio stations.
# -----------------
# amplified
#
# Some of the latest PC's, maybe most of them, are dropping the PS/2 legacy connector so check the back of your box before ordering this.
# -----------------
# latest
#
# ['NewerPC', 'DirectPC', 'newPC', 'latestPC', 'wirelessPC', 'recentPC', 'amplifiedPC', 'presentPC']
